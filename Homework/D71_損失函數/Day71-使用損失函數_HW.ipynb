# %% [markdown]
# #
#
# # 作業目標:
#
#     1. 藉由固定的 dataset, 來驗證不同loss function
#     2. Dataset 的特性跟我們選用的loss function 對accrancy 的影響
#
#
# # 作業重點:
#     請分別選用 "MSE", "binary _crossentropy"
#     查看Train/test accurancy and loss rate

# %% [markdown]
# # 導入必要的函數

# %%
from keras.datasets import cifar10
import numpy as np
np.random.seed(10)
# Out:
# WARNING:tensorflow:From c:\Users\louisan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # 資料準備

# %%
#取得Keras Dataset
(x_img_train,y_label_train),(x_img_test,y_label_test)=cifar10.load_data()

# %%
#確認 CIFAR10 Dataset 資料維度
print("train data:",'images:',x_img_train.shape,
      " labels:",y_label_train.shape) 
print("test  data:",'images:',x_img_test.shape ,
      " labels:",y_label_test.shape)
# Out:
# train data: images: (50000, 32, 32, 3)  labels: (50000, 1)
# test  data: images: (10000, 32, 32, 3)  labels: (10000, 1)

# %%
#資料正規化
x_img_train_normalize = x_img_train.astype('float32') / 255.0
x_img_test_normalize = x_img_test.astype('float32') / 255.0

# %%
#針對Label 做 ONE HOT ENCODE
from keras.utils import to_categorical
y_label_train_OneHot = to_categorical(y_label_train)
y_label_test_OneHot = to_categorical(y_label_test)
y_label_test_OneHot.shape
# Out:
# (10000, 10)

# %% [markdown]
# # 建立模型

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D

# %%
model = Sequential()
# Out:
# WARNING:tensorflow:From c:\Users\louisan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
#卷積層1

# %%
model.add(Conv2D(filters=32,kernel_size=(3,3),
                 input_shape=(32, 32,3), 
                 activation='relu', 
                 padding='same'))

# %%
model.add(Dropout(rate=0.25))

# %%
model.add(MaxPooling2D(pool_size=(2, 2)))
# Out:
# WARNING:tensorflow:From c:\Users\louisan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
#卷積層2與池化層2

# %%
model.add(Conv2D(filters=64, kernel_size=(3, 3), 
                 activation='relu', padding='same'))

# %%
model.add(Dropout(0.25))

# %%
model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
#建立神經網路(平坦層、隱藏層、輸出層)

# %%
model.add(Flatten())
model.add(Dropout(rate=0.25))

# %%
model.add(Dense(1024, activation='relu'))
model.add(Dropout(rate=0.25))

# %%
model.add(Dense(10, activation='softmax'))

# %%
#檢查model 的STACK
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 64)        18496
#
#  dropout_1 (Dropout)         (None, 16, 16, 64)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dropout_2 (Dropout)         (None, 4096)              0
#
#  dense (Dense)               (None, 1024)              4195328
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 4224970 (16.12 MB)
# Trainable params: 4224970 (16.12 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# # 載入之前訓練的模型

# %%
try:
    model.load_weights("SaveModel/cifarCnnModel.h5")
    print("載入模型成功!繼續訓練模型")
except :    
    print("載入模型失敗!開始訓練一個新模型")
# Out:
# 載入模型失敗!開始訓練一個新模型

# %% [markdown]
# # 訓練模型

# %%
model_mse = model
model_bi = model
model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
model_mse.compile(loss='mean_squared_error', optimizer='Adam', metrics=['accuracy'])
model_bi.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\louisan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
train_history = model.fit(x_img_train_normalize, y_label_train_OneHot,
                          validation_split=0.25,
                          epochs=10, batch_size=128, verbose=1)   

train_history_mse = model_mse.fit(x_img_train_normalize, y_label_train_OneHot,
                                  validation_split=0.25,
                                  epochs=10, batch_size=128, verbose=1)  

train_history_bi = model_bi.fit(x_img_train_normalize, y_label_train_OneHot,
                                validation_split=0.25,
                                epochs=10, batch_size=128, verbose=1)
# Out:
# Epoch 1/10
# WARNING:tensorflow:From c:\Users\louisan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\louisan\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 293/293 [==============================] - 17s 55ms/step - loss: 0.2480 - accuracy: 0.4216 - val_loss: 0.2323 - val_accuracy: 0.5374
# Epoch 2/10
# 293/293 [==============================] - 16s 55ms/step - loss: 0.1963 - accuracy: 0.5666 - val_loss: 0.1979 - val_accuracy: 0.5989
# Epoch 3/10
# 293/293 [==============================] - 16s 55ms/step - loss: 0.1750 - accuracy: 0.6237 - val_loss: 0.1822 - val_accuracy: 0.6535
# Epoch 4/10
# 293/293 [==============================] - 16s 55ms/step - loss: 0.1595 - accuracy: 0.6589 - val_loss: 0.1713 - val_accuracy: 0.6702
# Epoch 5/10
# 293/293 [==============================] - 27s 93ms/step - loss: 0.1489 - accuracy: 0.6877 - val_loss: 0.1656 - val_accuracy: 0.6791
# Epoch 6/10
# 293/293 [==============================] - 20s 67ms/step - loss: 0.1380 - accuracy: 0.7153 - val_loss: 0.1523 - val_accuracy: 0.7019
# Epoch 7/10
# 293/293 [==============================] - 17s 59ms/step - loss: 0.1298 - accuracy: 0.7381 - val_loss: 0.1468 - val_accuracy: 0.7093
# Epoch 8/10
# 293/293 [==============================] - 19s 66ms/step - loss: 0.1204 - accuracy: 0.7611 - val_loss: 0.1442 - val_accuracy: 0.7150
# Epoch 9/10
# 293/293 [==============================] - 32s 108ms/step - loss: 0.1118 - accuracy: 0.7834 - val_loss: 0.1397 - val_accuracy: 0.7284
# Epoch 10/10
# 293/293 [==============================] - 24s 81ms/step - loss: 0.1043 - accuracy: 0.8018 - val_loss: 0.1364 - val_accuracy: 0.7311
# Epoch 1/10
# 293/293 [==============================] - 17s 59ms/step - loss: 0.0960 - accuracy: 0.8221 - val_loss: 0.1335 - val_accuracy: 0.7362
# Epoch 2/10
# 293/293 [==============================] - 18s 60ms/step - loss: 0.0890 - accuracy: 0.8374 - val_loss: 0.1332 - val_accuracy: 0.7334
# Epoch 3/10
# 293/293 [==============================] - 22s 74ms/step - loss: 0.0823 - accuracy: 0.8555 - val_loss: 0.1323 - val_accuracy: 0.7360
# Epoch 4/10
# 293/293 [==============================] - 18s 60ms/step - loss: 0.0775 - accuracy: 0.8660 - val_loss: 0.1284 - val_accuracy: 0.7450
# Epoch 5/10
# 293/293 [==============================] - 18s 61ms/step - loss: 0.0718 - accuracy: 0.8802 - val_loss: 0.1283 - val_accuracy: 0.7429
# Epoch 6/10
# 293/293 [==============================] - 30s 103ms/step - loss: 0.0653 - accuracy: 0.8947 - val_loss: 0.1266 - val_accuracy: 0.7511
# Epoch 7/10
# 293/293 [==============================] - 32s 109ms/step - loss: 0.0617 - accuracy: 0.9035 - val_loss: 0.1298 - val_accuracy: 0.7452
# Epoch 8/10
# 293/293 [==============================] - 32s 109ms/step - loss: 0.0573 - accuracy: 0.9113 - val_loss: 0.1283 - val_accuracy: 0.7486
# Epoch 9/10
# 293/293 [==============================] - 32s 110ms/step - loss: 0.0535 - accuracy: 0.9213 - val_loss: 0.1276 - val_accuracy: 0.7489
# Epoch 10/10
# 293/293 [==============================] - 26s 89ms/step - loss: 0.0488 - accuracy: 0.9309 - val_loss: 0.1310 - val_accuracy: 0.7431
# Epoch 1/10
# 293/293 [==============================] - 22s 76ms/step - loss: 0.0464 - accuracy: 0.9353 - val_loss: 0.1289 - val_accuracy: 0.7472
# Epoch 2/10
# 293/293 [==============================] - 19s 63ms/step - loss: 0.0443 - accuracy: 0.9415 - val_loss: 0.1301 - val_accuracy: 0.7511
# Epoch 3/10
# 293/293 [==============================] - 17s 59ms/step - loss: 0.0418 - accuracy: 0.9432 - val_loss: 0.1323 - val_accuracy: 0.7489
# Epoch 4/10
# 293/293 [==============================] - 17s 58ms/step - loss: 0.0414 - accuracy: 0.9455 - val_loss: 0.1316 - val_accuracy: 0.7534
# Epoch 5/10
# 293/293 [==============================] - 17s 58ms/step - loss: 0.0393 - accuracy: 0.9486 - val_loss: 0.1317 - val_accuracy: 0.7542
# Epoch 6/10
# 293/293 [==============================] - 17s 58ms/step - loss: 0.0368 - accuracy: 0.9542 - val_loss: 0.1323 - val_accuracy: 0.7553
# Epoch 7/10
# 293/293 [==============================] - 17s 58ms/step - loss: 0.0352 - accuracy: 0.9566 - val_loss: 0.1333 - val_accuracy: 0.7552
# Epoch 8/10
# 293/293 [==============================] - 17s 58ms/step - loss: 0.0346 - accuracy: 0.9593 - val_loss: 0.1359 - val_accuracy: 0.7523
# Epoch 9/10
# 293/293 [==============================] - 17s 58ms/step - loss: 0.0340 - accuracy: 0.9591 - val_loss: 0.1382 - val_accuracy: 0.7475
# Epoch 10/10
# 293/293 [==============================] - 17s 58ms/step - loss: 0.0322 - accuracy: 0.9622 - val_loss: 0.1356 - val_accuracy: 0.7494

# %%
import matplotlib.pyplot as plt
def show_train_history(train_history,train_acc,test_acc):
    plt.plot(train_history.history[train_acc])
    plt.plot(train_history.history[test_acc])
    plt.title('Train History')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
show_train_history(train_history,"accuracy","val_accuracy")
show_train_history(train_history_mse,"accuracy","val_accuracy")
show_train_history(train_history_bi,"accuracy","val_accuracy")

# %%
show_train_history(train_history,"loss","val_loss")
show_train_history(train_history_mse,"loss","val_loss")
show_train_history(train_history_bi,"loss","val_loss")
